# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\mishr\OneDrive\Desktop\movie.zip")

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.tail()
# Out:
#                name rating   genre  year                          released  \
# 7663   More to Life    NaN   Drama  2020  October 23, 2020 (United States)
# 7664    Dream Round    NaN  Comedy  2020  February 7, 2020 (United States)
# 7665  Saving Mbango    NaN   Drama  2020         April 27, 2020 (Cameroon)
# 7666   It's Just Us    NaN   Drama  2020   October 1, 2020 (United States)
# 7667      Tee em el    NaN  Horror  2020   August 19, 2020 (United States)
#
#       score  votes       director         writer              star  \
# 7663    3.1   18.0  Joseph Ebanks  Joseph Ebanks      Shannon Bond
# 7664    4.7   36.0   Dusty Dukatz    Lisa Huston  Michael Saquella
# 7665    5.7   29.0   Nkanya Nkwai   Lynno Lovert      Onyama Laura
# 7666    NaN    NaN  James Randall  James Randall     Christina Roz
# 7667    5.7    7.0   Pereko Mosia   Pereko Mosia  Siyabonga Mabaso
#
#             country   budget  gross                    company  runtime
# ...

# %%
df.head(15)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
df.tail(10)
# Out:
#                            name     rating   genre  year  \
# 7658  Black Wall Street Burning          R   Drama  2020
# 7659                  I Am Fear  Not Rated  Horror  2020
# 7660           Aloha Surf Hotel        NaN  Comedy  2020
# 7661           Love by Drowning          R   Drama  2020
# 7662              The Robinsons        NaN  Action  2020
# 7663               More to Life        NaN   Drama  2020
# 7664                Dream Round        NaN  Comedy  2020
# 7665              Saving Mbango        NaN   Drama  2020
# 7666               It's Just Us        NaN   Drama  2020
# 7667                  Tee em el        NaN  Horror  2020
#
#                                released  score  votes            director  \
# 7658   February 7, 2020 (United States)    6.6   35.0        Marcus Brown
# 7659      March 3, 2020 (United States)    3.4  447.0       Kevin Shulman
# 7660   November 5, 2020 (United States)    7.1   14.0  Stefan C. Schaefer
# ...

# %%
df.shape
# Out:
# (7668, 15)

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.isnull()
# Out:
#        name  rating  genre   year  released  score  votes  director  writer  \
# 0     False   False  False  False     False  False  False     False   False
# 1     False   False  False  False     False  False  False     False   False
# 2     False   False  False  False     False  False  False     False   False
# 3     False   False  False  False     False  False  False     False   False
# 4     False   False  False  False     False  False  False     False   False
# ...     ...     ...    ...    ...       ...    ...    ...       ...     ...
# 7663  False    True  False  False     False  False  False     False   False
# 7664  False    True  False  False     False  False  False     False   False
# 7665  False    True  False  False     False  False  False     False   False
# 7666  False    True  False  False     False   True   True     False   False
# 7667  False    True  False  False     False  False  False     False   False
#
#        star  country  budget  gross  company  runtime
# ...

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df["votes"].fillna("1.0", inplace=True)

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          0
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df["votes"].mode()
# Out:
# 0    13000.0
# Name: votes, dtype: object

# %%
df['score']+df['votes']
# Out:
# 0        927008.4
# 1         65005.8
# 2       1200008.7
# 3        221007.7
# 4        108007.3
#           ...
# 7663         21.1
# 7664         40.7
# 7665         34.7
# 7666          NaN
# 7667         12.7
# Length: 7668, dtype: object

# %%
df[(df.score>5)&(df.genre=='Drama')]
# Out:
#                            name rating  genre  year  \
# 0                   The Shining      R  Drama  1980
# 13              Ordinary People      R  Drama  1980
# 15            Somewhere in Time     PG  Drama  1980
# 16                         Fame      R  Drama  1980
# 24                 Urban Cowboy     PG  Drama  1980
# ...                         ...    ...    ...   ...
# 7642           A Brother's Love    NaN  Drama  2019
# 7646          The Invisible Man      R  Drama  2020
# 7657                       Leap    NaN  Drama  2020
# 7658  Black Wall Street Burning      R  Drama  2020
# 7665              Saving Mbango    NaN  Drama  2020
#
#                                 released  score     votes           director  \
# 0          June 13, 1980 (United States)    8.4  927000.0    Stanley Kubrick
# 13    September 19, 1980 (United States)    7.7   49000.0     Robert Redford
# 15       October 3, 1980 (United States)    7.2   27000.0     Jeannot Szwarc
# ...

# %%
df['genre']
# Out:
# 0           Drama
# 1       Adventure
# 2          Action
# 3          Comedy
# 4          Comedy
#           ...
# 7663        Drama
# 7664       Comedy
# 7665        Drama
# 7666        Drama
# 7667       Horror
# Name: genre, Length: 7668, dtype: object

# %%
df['genre'].unique()
# Out:
# array(['Drama', 'Adventure', 'Action', 'Comedy', 'Horror', 'Biography',
#        'Crime', 'Fantasy', 'Family', 'Sci-Fi', 'Animation', 'Romance',
#        'Music', 'Western', 'Thriller', 'History', 'Mystery', 'Sport',
#        'Musical'], dtype=object)

# %%
df[df['genre']=='Comedy']
# Out:
#                     name rating   genre  year  \
# 3              Airplane!     PG  Comedy  1980
# 4             Caddyshack      R  Comedy  1980
# 17                9 to 5     PG  Comedy  1980
# 19            Stir Crazy      R  Comedy  1980
# 26       Little Darlings      R  Comedy  1980
# ...                  ...    ...     ...   ...
# 7626  No Manches Frida 2      R  Comedy  2019
# 7633          Tod@s Caen  PG-13  Comedy  2019
# 7656               Tulsa  PG-13  Comedy  2020
# 7660    Aloha Surf Hotel    NaN  Comedy  2020
# 7664         Dream Round    NaN  Comedy  2020
#
#                                released  score     votes            director  \
# 3          July 2, 1980 (United States)    7.7  221000.0        Jim Abrahams
# 4         July 25, 1980 (United States)    7.3  108000.0        Harold Ramis
# 17    December 19, 1980 (United States)    6.9   29000.0       Colin Higgins
# 19    December 12, 1980 (United States)    6.8   26000.0      Sidney Poitier
# ...

# %%
df['score']
# Out:
# 0       8.4
# 1       5.8
# 2       8.7
# 3       7.7
# 4       7.3
#        ...
# 7663    3.1
# 7664    4.7
# 7665    5.7
# 7666    NaN
# 7667    5.7
# Name: score, Length: 7668, dtype: float64

# %%
df['score'].min()
# Out:
# 1.9

# %%
df['score'].max()
# Out:
# 9.3

# %%
df['score'].sum()
# Out:
# 48982.5

# %%
df['year'][50:]
# Out:
# 50      1980
# 51      1980
# 52      1980
# 53      1980
# 54      1980
#         ...
# 7663    2020
# 7664    2020
# 7665    2020
# 7666    2020
# 7667    2020
# Name: year, Length: 7618, dtype: int64

# %%
df['year'][:50:2]
# Out:
# 0     1980
# 2     1980
# 4     1980
# 6     1980
# 8     1980
# 10    1980
# 12    1980
# 14    1980
# 16    1980
# 18    1980
# 20    1980
# 22    1980
# 24    1980
# 26    1980
# 28    1980
# 30    1980
# 32    1980
# 34    1980
# 36    1980
# 38    1980
# 40    1980
# 42    1980
# 44    1980
# 46    1980
# 48    1980
# Name: year, dtype: int64

# %%
df[['name','country']][:30]
# Out:
#                                               name         country
# 0                                      The Shining  United Kingdom
# 1                                  The Blue Lagoon   United States
# 2   Star Wars: Episode V - The Empire Strikes Back   United States
# 3                                        Airplane!   United States
# 4                                       Caddyshack   United States
# 5                                  Friday the 13th   United States
# 6                               The Blues Brothers   United States
# 7                                      Raging Bull   United States
# 8                                      Superman II   United States
# 9                                  The Long Riders   United States
# 10                           Any Which Way You Can   United States
# 11                          The Gods Must Be Crazy    South Africa
# 12                                          Popeye   United States
# ...

# %%
df==type("object")
# Out:
#        name  rating  genre   year  released  score  votes  director  writer  \
# 0     False   False  False  False     False  False  False     False   False
# 1     False   False  False  False     False  False  False     False   False
# 2     False   False  False  False     False  False  False     False   False
# 3     False   False  False  False     False  False  False     False   False
# 4     False   False  False  False     False  False  False     False   False
# ...     ...     ...    ...    ...       ...    ...    ...       ...     ...
# 7663  False   False  False  False     False  False  False     False   False
# 7664  False   False  False  False     False  False  False     False   False
# 7665  False   False  False  False     False  False  False     False   False
# 7666  False   False  False  False     False  False  False     False   False
# 7667  False   False  False  False     False  False  False     False   False
#
#        star  country  budget  gross  company  runtime
# ...

# %%
df.dtypes[df.dtypes=='object']
# Out:
# name        object
# rating      object
# genre       object
# released    object
# votes       object
# director    object
# writer      object
# star        object
# country     object
# company     object
# dtype: object

# %%
df[df.dtypes[df.dtypes=='object'].index]
# Out:
#                                                 name rating      genre  \
# 0                                        The Shining      R      Drama
# 1                                    The Blue Lagoon      R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                          Airplane!     PG     Comedy
# 4                                         Caddyshack      R     Comedy
# ...                                              ...    ...        ...
# 7663                                    More to Life    NaN      Drama
# 7664                                     Dream Round    NaN     Comedy
# 7665                                   Saving Mbango    NaN      Drama
# 7666                                    It's Just Us    NaN      Drama
# 7667                                       Tee em el    NaN     Horror
#
#                               released      votes         director  \
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7663    False
# 7664    False
# 7665    False
# 7666    False
# 7667    False
# Length: 7668, dtype: bool

# %%
df.duplicated().shape
# Out:
# (7668,)

# %%
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.drop_duplicates().shape
# Out:
# (7668, 15)

# %%
df.drop(['rating'],axis=1)
# Out:
#                                                 name      genre  year  \
# 0                                        The Shining      Drama  1980
# 1                                    The Blue Lagoon  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     Action  1980
# 3                                          Airplane!     Comedy  1980
# 4                                         Caddyshack     Comedy  1980
# ...                                              ...        ...   ...
# 7663                                    More to Life      Drama  2020
# 7664                                     Dream Round     Comedy  2020
# 7665                                   Saving Mbango      Drama  2020
# 7666                                    It's Just Us      Drama  2020
# 7667                                       Tee em el     Horror  2020
#
#                               released  score      votes         director  \
# ...

# %%
df.drop(['rating','runtime'],axis=1)
# Out:
#                                                 name      genre  year  \
# 0                                        The Shining      Drama  1980
# 1                                    The Blue Lagoon  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     Action  1980
# 3                                          Airplane!     Comedy  1980
# 4                                         Caddyshack     Comedy  1980
# ...                                              ...        ...   ...
# 7663                                    More to Life      Drama  2020
# 7664                                     Dream Round     Comedy  2020
# 7665                                   Saving Mbango      Drama  2020
# 7666                                    It's Just Us      Drama  2020
# 7667                                       Tee em el     Horror  2020
#
#                               released  score      votes         director  \
# ...

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.drop(df.columns[[1,12,14]],axis=1)
# Out:
#                                                 name      genre  year  \
# 0                                        The Shining      Drama  1980
# 1                                    The Blue Lagoon  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     Action  1980
# 3                                          Airplane!     Comedy  1980
# 4                                         Caddyshack     Comedy  1980
# ...                                              ...        ...   ...
# 7663                                    More to Life      Drama  2020
# 7664                                     Dream Round     Comedy  2020
# 7665                                   Saving Mbango      Drama  2020
# 7666                                    It's Just Us      Drama  2020
# 7667                                       Tee em el     Horror  2020
#
#                               released  score      votes         director  \
# ...

# %%
df=pd.DataFrame({"name":['a','b','c','a','b','c','d'],"s_1":[2,3,4,5,6,7,8],"s_2":[8,7,6,5,4,3,2]})

# %%
df
# Out:
#   name  s_1  s_2
# 0    a    2    8
# 1    b    3    7
# 2    c    4    6
# 3    a    5    5
# 4    b    6    4
# 5    c    7    3
# 6    d    8    2

# %%
df1=df.groupby("name")

# %%
df1

# %%
for i,j in df1:
    print(i)
    print(j)
    print( )
# Out:
# a
#   name  s_1  s_2
# 0    a    2    8
# 3    a    5    5
#
# b
#   name  s_1  s_2
# 1    b    3    7
# 4    b    6    4
#
# c
#   name  s_1  s_2
# 2    c    4    6
# 5    c    7    3
#
# d
#   name  s_1  s_2
# 6    d    8    2

# %%
df.groupby('name').mean()
# Out:
#       s_1  s_2
# name
# a     3.5  6.5
# b     4.5  5.5
# c     5.5  4.5
# d     8.0  2.0

# %%
df[df.name=='d']
# Out:
#   name  s_1  s_2
# 6    d    8    2

# %%
df1=df.groupby("name")
df1.first()
# Out:
#       s_1  s_2
# name
# a       2    8
# b       3    7
# c       4    6
# d       8    2
